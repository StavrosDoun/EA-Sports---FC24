# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,GridSearchCV
import tqdm
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
from mrmr import mrmr_classif
import matplotlib.ticker as mtick

# %%
df=pd.read_csv('player_stats.csv', sep=',', encoding='latin-1')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                         player   country  height  weight  age            club  \
# 0     Cristian Castro Devenish  Colombia     192      84   22  Atl. Nacional
# 1             Silaldo Taffarel    Brazil     181      80   31    Corinthians
# 2                Thomas DÃ¤hne   Germany     193      84   29  Holstein Kiel
# 3            Michael Sollbauer   Austria     187      86   33  SK Rapid Wien
# 4                Diego Segovia   Uruguay     191      80   23  Independiente
# ...                        ...       ...     ...     ...  ...             ...
# 5675             Karim Benzema    France     185      81   35     Real Madrid
# 5676             Mohamed Salah     Egypt     175      71   31       Liverpool
# 5677                 Neymar Jr    Brazil     175      68   31        Paris SG
# 5678         Cristiano Ronaldo  Portugal     187      83   38        Al Nassr
# 5679        Zlatan Ibrahimovi?    Sweden     195     102   41           Milan
#
#       ball_control  dribbling marking  slide_tackle  stand_tackle  aggression  \
# 0               55         43     NaN            68            73          72
# 1               69         70     NaN            56            58          62
# 2               25         12     NaN            13            16          27
# 3               46         48     NaN            66            69          71
# 4               14          8     NaN            14            16          28
# ...            ...        ...     ...           ...           ...         ...
# 5675            91         87    None            18            24          63
# 5676            86         88    None            41            43          63
# 5677            94         95    None            29            32          63
# 5678            87         81    None            24            32          62
# 5679            85         75    None            24            37          84
#
#       reactions  att_position  interceptions  vision  composure  crossing  \
# 0            68            30             65      30         50        33
# 1            70            69             70      64         54        60
# 2            65            17             20      49         48        14
# 3            64            48             66      29         70        44
# 4            50            10             12      38         34        11
# ...         ...           ...            ...     ...        ...       ...
# 5675         92            92             39      89         90        75
# 5676         92            91             55      84         90        80
# 5677         88            86             37      90         93        83
# 5678         90            93             29      76         94        78
# 5679         77            88             20      83         90        71
#
#       short_pass  long_pass  acceleration  stamina  strength  balance  \
# 0             64         49            41       55        86       40
# 1             63         63            64       87        81       42
# 2             35         18            46       38        68       41
# 3             58         53            35       73        82       56
# 4             23         20            38       28        64       24
# ...          ...        ...           ...      ...       ...      ...
# 5675          89         76            79       82        82       72
# 5676          84         77            89       87        76       91
# 5677          85         81            88       79        52       82
# 5678          78         70            76       70        75       67
# 5679          77         72            55       34        85       51
#
#       sprint_speed  agility  jumping  heading  shot_power  finishing  \
# 0               52       43       51       64          54         30
# 1               67       65       65       54          60         64
# 2               48       36       60       17          51         14
# 3               63       57       80       67          32         24
# 4               31       34       27       13          48          4
# ...            ...      ...      ...      ...         ...        ...
# 5675            80       78       79       90          87         92
# 5676            89       89       69       59          82         92
# 5677            86       93       62       63          79         83
# 5678            82       77       95       89          93         91
# 5679            61       67       77       82          86         84
#
#       long_shots  curve  fk_acc  penalties  volleys  gk_positioning  \
# 0             31     32      34         41       33              10
# 1             68     65      62         48       46              12
# 2             20     20      15         26       16              64
# 3             33     25      13         22       19              10
# 4              6      9      10         16        5              61
# ...          ...    ...     ...        ...      ...             ...
# 5675          80     82      73         84       88               5
# 5676          84     84      69         86       83              11
# 5677          81     88      87         91       86              15
# 5678          88     79      75         90       85              14
# 5679          85     79      74         80       87               9
#
#       gk_diving  gk_handling  gk_kicking  gk_reflexes        value
# 0            11            6           7            9   $1.400.000
# 1            15           14           8           14     $975.00
# 2            74           65          68           74   $1.100.000
# 3            10            8          14            9     $650.00
# 4            59           62          64           64     $300.00
# ...         ...          ...         ...          ...          ...
# 5675         13           11           5            7  $64.000.000
# 5676         14           14           9           14  $99.500.000
# 5677          9            9          15           11  $99.500.000
# 5678          7           11          15           11  $31.000.000
# 5679         13           15          10           12  $10.500.000
#
# [5680 rows x 41 columns]

# %%
df.head()
# Out:
#                      player   country  height  weight  age            club  \
# 0  Cristian Castro Devenish  Colombia     192      84   22  Atl. Nacional
# 1          Silaldo Taffarel    Brazil     181      80   31    Corinthians
# 2             Thomas DÃ¤hne   Germany     193      84   29  Holstein Kiel
# 3         Michael Sollbauer   Austria     187      86   33  SK Rapid Wien
# 4             Diego Segovia   Uruguay     191      80   23  Independiente
#
#    ball_control  dribbling marking  slide_tackle  stand_tackle  aggression  \
# 0            55         43     NaN            68            73          72
# 1            69         70     NaN            56            58          62
# 2            25         12     NaN            13            16          27
# 3            46         48     NaN            66            69          71
# 4            14          8     NaN            14            16          28
#
#    reactions  att_position  interceptions  vision  composure  crossing  \
# 0         68            30             65      30         50        33
# 1         70            69             70      64         54        60
# 2         65            17             20      49         48        14
# 3         64            48             66      29         70        44
# 4         50            10             12      38         34        11
#
#    short_pass  long_pass  acceleration  stamina  strength  balance  \
# 0          64         49            41       55        86       40
# 1          63         63            64       87        81       42
# 2          35         18            46       38        68       41
# 3          58         53            35       73        82       56
# 4          23         20            38       28        64       24
#
#    sprint_speed  agility  jumping  heading  shot_power  finishing  long_shots  \
# 0            52       43       51       64          54         30          31
# 1            67       65       65       54          60         64          68
# 2            48       36       60       17          51         14          20
# 3            63       57       80       67          32         24          33
# 4            31       34       27       13          48          4           6
#
#    curve  fk_acc  penalties  volleys  gk_positioning  gk_diving  gk_handling  \
# 0     32      34         41       33              10         11            6
# 1     65      62         48       46              12         15           14
# 2     20      15         26       16              64         74           65
# 3     25      13         22       19              10         10            8
# 4      9      10         16        5              61         59           62
#
#    gk_kicking  gk_reflexes       value
# 0           7            9  $1.400.000
# 1           8           14    $975.00
# 2          68           74  $1.100.000
# 3          14            9    $650.00
# 4          64           64    $300.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 41 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player          5680 non-null   object
#  1   country         5680 non-null   object
#  2   height          5680 non-null   int64
#  3   weight          5680 non-null   int64
#  4   age             5680 non-null   int64
#  5   club            5680 non-null   object
#  6   ball_control    5680 non-null   int64
#  7   dribbling       5680 non-null   int64
#  8   marking         5522 non-null   object
#  9   slide_tackle    5680 non-null   int64
#  10  stand_tackle    5680 non-null   int64
#  11  aggression      5680 non-null   int64
#  12  reactions       5680 non-null   int64
#  13  att_position    5680 non-null   int64
#  14  interceptions   5680 non-null   int64
#  15  vision          5680 non-null   int64
#  16  composure       5680 non-null   int64
#  17  crossing        5680 non-null   int64
#  18  short_pass      5680 non-null   int64
#  19  long_pass       5680 non-null   int64
#  20  acceleration    5680 non-null   int64
#  21  stamina         5680 non-null   int64
#  22  strength        5680 non-null   int64
#  23  balance         5680 non-null   int64
#  24  sprint_speed    5680 non-null   int64
#  25  agility         5680 non-null   int64
#  26  jumping         5680 non-null   int64
#  27  heading         5680 non-null   int64
#  28  shot_power      5680 non-null   int64
#  29  finishing       5680 non-null   int64
#  30  long_shots      5680 non-null   int64
#  31  curve           5680 non-null   int64
#  32  fk_acc          5680 non-null   int64
#  33  penalties       5680 non-null   int64
#  34  volleys         5680 non-null   int64
#  35  gk_positioning  5680 non-null   int64
#  36  gk_diving       5680 non-null   int64
#  37  gk_handling     5680 non-null   int64
#  38  gk_kicking      5680 non-null   int64
#  39  gk_reflexes     5680 non-null   int64
#  40  value           5680 non-null   object
# dtypes: int64(36), object(5)
# memory usage: 1.8+ MB

# %%
df['marking'].unique()
# Out:
# array([nan, 'None'], dtype=object)

# %%
df.drop(columns='marking',inplace=True)

# %%
df_3=df.copy()

# %%
df_3= df_3.replace('[\$,]', '', regex=True)

# %%
df_3=df_3.replace('[\.,]', '', regex=True)

# %%
df_3['value']=pd.to_numeric(df_3['value'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 40 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player          5680 non-null   object
#  1   country         5680 non-null   object
#  2   height          5680 non-null   int64
#  3   weight          5680 non-null   int64
#  4   age             5680 non-null   int64
#  5   club            5680 non-null   object
#  6   ball_control    5680 non-null   int64
#  7   dribbling       5680 non-null   int64
#  8   slide_tackle    5680 non-null   int64
#  9   stand_tackle    5680 non-null   int64
#  10  aggression      5680 non-null   int64
#  11  reactions       5680 non-null   int64
#  12  att_position    5680 non-null   int64
#  13  interceptions   5680 non-null   int64
#  14  vision          5680 non-null   int64
#  15  composure       5680 non-null   int64
#  16  crossing        5680 non-null   int64
#  17  short_pass      5680 non-null   int64
#  18  long_pass       5680 non-null   int64
#  19  acceleration    5680 non-null   int64
#  20  stamina         5680 non-null   int64
#  21  strength        5680 non-null   int64
#  22  balance         5680 non-null   int64
#  23  sprint_speed    5680 non-null   int64
#  24  agility         5680 non-null   int64
#  25  jumping         5680 non-null   int64
#  26  heading         5680 non-null   int64
#  27  shot_power      5680 non-null   int64
#  28  finishing       5680 non-null   int64
#  29  long_shots      5680 non-null   int64
#  30  curve           5680 non-null   int64
#  31  fk_acc          5680 non-null   int64
#  32  penalties       5680 non-null   int64
#  33  volleys         5680 non-null   int64
#  34  gk_positioning  5680 non-null   int64
#  35  gk_diving       5680 non-null   int64
#  36  gk_handling     5680 non-null   int64
#  37  gk_kicking      5680 non-null   int64
#  38  gk_reflexes     5680 non-null   int64
#  39  value           5680 non-null   object
# dtypes: int64(36), object(4)
# memory usage: 1.7+ MB

# %%
df_2=df.copy()

# %%
df_2 = df_2.replace('[\$,]', '', regex=True)

# %%
df_2 = df_2.replace('[\.,]', '', regex=True)

# %%
df_2.drop(columns=['player','country','club'],inplace=True)

# %%
df_2
# Out:
#       height  weight  age  ball_control  dribbling  slide_tackle  \
# 0        192      84   22            55         43            68
# 1        181      80   31            69         70            56
# 2        193      84   29            25         12            13
# 3        187      86   33            46         48            66
# 4        191      80   23            14          8            14
# ...      ...     ...  ...           ...        ...           ...
# 5675     185      81   35            91         87            18
# 5676     175      71   31            86         88            41
# 5677     175      68   31            94         95            29
# 5678     187      83   38            87         81            24
# 5679     195     102   41            85         75            24
#
#       stand_tackle  aggression  reactions  att_position  interceptions  \
# 0               73          72         68            30             65
# 1               58          62         70            69             70
# 2               16          27         65            17             20
# 3               69          71         64            48             66
# 4               16          28         50            10             12
# ...            ...         ...        ...           ...            ...
# 5675            24          63         92            92             39
# 5676            43          63         92            91             55
# 5677            32          63         88            86             37
# 5678            32          62         90            93             29
# 5679            37          84         77            88             20
#
#       vision  composure  crossing  short_pass  long_pass  acceleration  \
# 0         30         50        33          64         49            41
# 1         64         54        60          63         63            64
# 2         49         48        14          35         18            46
# 3         29         70        44          58         53            35
# 4         38         34        11          23         20            38
# ...      ...        ...       ...         ...        ...           ...
# 5675      89         90        75          89         76            79
# 5676      84         90        80          84         77            89
# 5677      90         93        83          85         81            88
# 5678      76         94        78          78         70            76
# 5679      83         90        71          77         72            55
#
#       stamina  strength  balance  sprint_speed  agility  jumping  heading  \
# 0          55        86       40            52       43       51       64
# 1          87        81       42            67       65       65       54
# 2          38        68       41            48       36       60       17
# 3          73        82       56            63       57       80       67
# 4          28        64       24            31       34       27       13
# ...       ...       ...      ...           ...      ...      ...      ...
# 5675       82        82       72            80       78       79       90
# 5676       87        76       91            89       89       69       59
# 5677       79        52       82            86       93       62       63
# 5678       70        75       67            82       77       95       89
# 5679       34        85       51            61       67       77       82
#
#       shot_power  finishing  long_shots  curve  fk_acc  penalties  volleys  \
# 0             54         30          31     32      34         41       33
# 1             60         64          68     65      62         48       46
# 2             51         14          20     20      15         26       16
# 3             32         24          33     25      13         22       19
# 4             48          4           6      9      10         16        5
# ...          ...        ...         ...    ...     ...        ...      ...
# 5675          87         92          80     82      73         84       88
# 5676          82         92          84     84      69         86       83
# 5677          79         83          81     88      87         91       86
# 5678          93         91          88     79      75         90       85
# 5679          86         84          85     79      74         80       87
#
#       gk_positioning  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0                 10         11            6           7            9
# 1                 12         15           14           8           14
# 2                 64         74           65          68           74
# 3                 10         10            8          14            9
# 4                 61         59           62          64           64
# ...              ...        ...          ...         ...          ...
# 5675               5         13           11           5            7
# 5676              11         14           14           9           14
# 5677              15          9            9          15           11
# 5678              14          7           11          15           11
# 5679               9         13           15          10           12
#
#          value
# 0      1400000
# 1       97500
# 2      1100000
# 3       65000
# 4       30000
# ...        ...
# 5675  64000000
# 5676  99500000
# 5677  99500000
# 5678  31000000
# 5679  10500000
#
# [5680 rows x 37 columns]

# %%
df_2['value']=pd.to_numeric(df_2['value'])

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 37 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          5680 non-null   int64
#  1   weight          5680 non-null   int64
#  2   age             5680 non-null   int64
#  3   ball_control    5680 non-null   int64
#  4   dribbling       5680 non-null   int64
#  5   slide_tackle    5680 non-null   int64
#  6   stand_tackle    5680 non-null   int64
#  7   aggression      5680 non-null   int64
#  8   reactions       5680 non-null   int64
#  9   att_position    5680 non-null   int64
#  10  interceptions   5680 non-null   int64
#  11  vision          5680 non-null   int64
#  12  composure       5680 non-null   int64
#  13  crossing        5680 non-null   int64
#  14  short_pass      5680 non-null   int64
#  15  long_pass       5680 non-null   int64
#  16  acceleration    5680 non-null   int64
#  17  stamina         5680 non-null   int64
#  18  strength        5680 non-null   int64
#  19  balance         5680 non-null   int64
#  20  sprint_speed    5680 non-null   int64
#  21  agility         5680 non-null   int64
#  22  jumping         5680 non-null   int64
#  23  heading         5680 non-null   int64
#  24  shot_power      5680 non-null   int64
#  25  finishing       5680 non-null   int64
#  26  long_shots      5680 non-null   int64
#  27  curve           5680 non-null   int64
#  28  fk_acc          5680 non-null   int64
#  29  penalties       5680 non-null   int64
#  30  volleys         5680 non-null   int64
#  31  gk_positioning  5680 non-null   int64
#  32  gk_diving       5680 non-null   int64
#  33  gk_handling     5680 non-null   int64
#  34  gk_kicking      5680 non-null   int64
#  35  gk_reflexes     5680 non-null   int64
#  36  value           5680 non-null   int64
# dtypes: int64(37)
# memory usage: 1.6 MB

# %%
X=df_2.drop(columns='value')
y=df_2['value']

# %%
X
# Out:
#       height  weight  age  ball_control  dribbling  slide_tackle  \
# 0        192      84   22            55         43            68
# 1        181      80   31            69         70            56
# 2        193      84   29            25         12            13
# 3        187      86   33            46         48            66
# 4        191      80   23            14          8            14
# ...      ...     ...  ...           ...        ...           ...
# 5675     185      81   35            91         87            18
# 5676     175      71   31            86         88            41
# 5677     175      68   31            94         95            29
# 5678     187      83   38            87         81            24
# 5679     195     102   41            85         75            24
#
#       stand_tackle  aggression  reactions  att_position  interceptions  \
# 0               73          72         68            30             65
# 1               58          62         70            69             70
# 2               16          27         65            17             20
# 3               69          71         64            48             66
# 4               16          28         50            10             12
# ...            ...         ...        ...           ...            ...
# 5675            24          63         92            92             39
# 5676            43          63         92            91             55
# 5677            32          63         88            86             37
# 5678            32          62         90            93             29
# 5679            37          84         77            88             20
#
#       vision  composure  crossing  short_pass  long_pass  acceleration  \
# 0         30         50        33          64         49            41
# 1         64         54        60          63         63            64
# 2         49         48        14          35         18            46
# 3         29         70        44          58         53            35
# 4         38         34        11          23         20            38
# ...      ...        ...       ...         ...        ...           ...
# 5675      89         90        75          89         76            79
# 5676      84         90        80          84         77            89
# 5677      90         93        83          85         81            88
# 5678      76         94        78          78         70            76
# 5679      83         90        71          77         72            55
#
#       stamina  strength  balance  sprint_speed  agility  jumping  heading  \
# 0          55        86       40            52       43       51       64
# 1          87        81       42            67       65       65       54
# 2          38        68       41            48       36       60       17
# 3          73        82       56            63       57       80       67
# 4          28        64       24            31       34       27       13
# ...       ...       ...      ...           ...      ...      ...      ...
# 5675       82        82       72            80       78       79       90
# 5676       87        76       91            89       89       69       59
# 5677       79        52       82            86       93       62       63
# 5678       70        75       67            82       77       95       89
# 5679       34        85       51            61       67       77       82
#
#       shot_power  finishing  long_shots  curve  fk_acc  penalties  volleys  \
# 0             54         30          31     32      34         41       33
# 1             60         64          68     65      62         48       46
# 2             51         14          20     20      15         26       16
# 3             32         24          33     25      13         22       19
# 4             48          4           6      9      10         16        5
# ...          ...        ...         ...    ...     ...        ...      ...
# 5675          87         92          80     82      73         84       88
# 5676          82         92          84     84      69         86       83
# 5677          79         83          81     88      87         91       86
# 5678          93         91          88     79      75         90       85
# 5679          86         84          85     79      74         80       87
#
#       gk_positioning  gk_diving  gk_handling  gk_kicking  gk_reflexes
# 0                 10         11            6           7            9
# 1                 12         15           14           8           14
# 2                 64         74           65          68           74
# 3                 10         10            8          14            9
# 4                 61         59           62          64           64
# ...              ...        ...          ...         ...          ...
# 5675               5         13           11           5            7
# 5676              11         14           14           9           14
# 5677              15          9            9          15           11
# 5678              14          7           11          15           11
# 5679               9         13           15          10           12
#
# [5680 rows x 36 columns]

# %%
y
# Out:
# 0        1400000
# 1          97500
# 2        1100000
# 3          65000
# 4          30000
#           ...
# 5675    64000000
# 5676    99500000
# 5677    99500000
# 5678    31000000
# 5679    10500000
# Name: value, Length: 5680, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state = 13)

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.10967517754888523

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 6480296.49643962

# %% [markdown]
# # Use scaling to help the score

# %% [markdown]
# # LogisticRegression

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 5578146.1487458

# %%
r2_score(y_test, y_pred)
# Out:
# 0.3403121194708699

# %% [markdown]
# # LinearRegresion

# %%
lr_1=LinearRegression()

# %%
lr_1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr_1.predict(X_test)

# %%
r2_score(y_test, y_pred_lr)
# Out:
# 0.31149601326133536

# %%
mean_squared_error(y_test, y_pred_lr,squared=False)
# Out:
# 5698674.686459596

# %% [markdown]
# # ElasticNet

# %%
el=ElasticNet()

# %%
el.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred_el=el.predict(X_test)

# %%
r2_score(y_test, y_pred_el)
# Out:
# 0.2948368487160766

# %%
mean_squared_error(y_test, y_pred_el,squared=False)
# Out:
# 5767205.688703776

# %% [markdown]
# # DecisionTreeRegressor

# %%
DTR=DecisionTreeRegressor(max_depth=21,random_state=10)

# %%
DTR.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=21, random_state=10)

# %%
y_pred_DTR=DTR.predict(X_test)

# %%
r2_score(y_test, y_pred_DTR)
# Out:
# 0.7413988271311442

# %%
mean_squared_error(y_test, y_pred_DTR,squared=False)
# Out:
# 3492495.708033636

# %%
mrmr_classif(X,y, K=10)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 33.68it/s]
# ['reactions',
#  'height',
#  'composure',
#  'shot_power',
#  'short_pass',
#  'vision',
#  'ball_control',
#  'long_pass',
#  'age',
#  'stamina']

# %% [markdown]
# # Ridge

# %%
r=Ridge()

# %%
r.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_pred_Ridge=r.predict(X_test)

# %%
r2_score(y_test, y_pred_Ridge)
# Out:
# 0.311539482133946

# %%
mean_squared_error(y_test, y_pred_Ridge,squared=False)
# Out:
# 5698494.789989295

# %%
rgres=[r,DTR,el,lr_1,lr]

# %%
counter=0
name=None
final_pred=None
pred=None
for rgre in rgres:
    parameters={}
    CV = GridSearchCV(rgre,parameters)
    CV.fit(X_train,y_train)
    pred=CV.predict(X_test)
    if counter<r2_score(y_test, pred):
        counter=r2_score(y_test, pred)
        name=rgre
        final_pred=pred
print(final_pred)
print(name)
print(counter)
print(mean_squared_error(y_test, final_pred,squared=False))
# Out:
# [1380000.           36040.         3100000.         ...   11492.26190476
#    11492.26190476 1000000.        ]
# DecisionTreeRegressor(max_depth=21, random_state=10)
# 0.7413988271311442
# 3492495.708033636

# %%
df_2
# Out:
#       height  weight  age  ball_control  dribbling  slide_tackle  \
# 0        192      84   22            55         43            68
# 1        181      80   31            69         70            56
# 2        193      84   29            25         12            13
# 3        187      86   33            46         48            66
# 4        191      80   23            14          8            14
# ...      ...     ...  ...           ...        ...           ...
# 5675     185      81   35            91         87            18
# 5676     175      71   31            86         88            41
# 5677     175      68   31            94         95            29
# 5678     187      83   38            87         81            24
# 5679     195     102   41            85         75            24
#
#       stand_tackle  aggression  reactions  att_position  interceptions  \
# 0               73          72         68            30             65
# 1               58          62         70            69             70
# 2               16          27         65            17             20
# 3               69          71         64            48             66
# 4               16          28         50            10             12
# ...            ...         ...        ...           ...            ...
# 5675            24          63         92            92             39
# 5676            43          63         92            91             55
# 5677            32          63         88            86             37
# 5678            32          62         90            93             29
# 5679            37          84         77            88             20
#
#       vision  composure  crossing  short_pass  long_pass  acceleration  \
# 0         30         50        33          64         49            41
# 1         64         54        60          63         63            64
# 2         49         48        14          35         18            46
# 3         29         70        44          58         53            35
# 4         38         34        11          23         20            38
# ...      ...        ...       ...         ...        ...           ...
# 5675      89         90        75          89         76            79
# 5676      84         90        80          84         77            89
# 5677      90         93        83          85         81            88
# 5678      76         94        78          78         70            76
# 5679      83         90        71          77         72            55
#
#       stamina  strength  balance  sprint_speed  agility  jumping  heading  \
# 0          55        86       40            52       43       51       64
# 1          87        81       42            67       65       65       54
# 2          38        68       41            48       36       60       17
# 3          73        82       56            63       57       80       67
# 4          28        64       24            31       34       27       13
# ...       ...       ...      ...           ...      ...      ...      ...
# 5675       82        82       72            80       78       79       90
# 5676       87        76       91            89       89       69       59
# 5677       79        52       82            86       93       62       63
# 5678       70        75       67            82       77       95       89
# 5679       34        85       51            61       67       77       82
#
#       shot_power  finishing  long_shots  curve  fk_acc  penalties  volleys  \
# 0             54         30          31     32      34         41       33
# 1             60         64          68     65      62         48       46
# 2             51         14          20     20      15         26       16
# 3             32         24          33     25      13         22       19
# 4             48          4           6      9      10         16        5
# ...          ...        ...         ...    ...     ...        ...      ...
# 5675          87         92          80     82      73         84       88
# 5676          82         92          84     84      69         86       83
# 5677          79         83          81     88      87         91       86
# 5678          93         91          88     79      75         90       85
# 5679          86         84          85     79      74         80       87
#
#       gk_positioning  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0                 10         11            6           7            9
# 1                 12         15           14           8           14
# 2                 64         74           65          68           74
# 3                 10         10            8          14            9
# 4                 61         59           62          64           64
# ...              ...        ...          ...         ...          ...
# 5675               5         13           11           5            7
# 5676              11         14           14           9           14
# 5677              15          9            9          15           11
# 5678              14          7           11          15           11
# 5679               9         13           15          10           12
#
#          value
# 0      1400000
# 1        97500
# 2      1100000
# 3        65000
# 4        30000
# ...        ...
# 5675  64000000
# 5676  99500000
# 5677  99500000
# 5678  31000000
# 5679  10500000
#
# [5680 rows x 37 columns]

# %%
countries=df_3.groupby('country')['value'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
asto_se_emena=df_3.groupby('player')['value'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
asto_se_emena = asto_se_emena.replace('[\Ã©,]', 'e', regex=True)

# %%
asto_se_emena
# Out:
#                  player      value
# 0        Kylian Mbappee  153500000
# 1        Erling Haaland  123000000
# 2       Kevin De Bruyne  107500000
# 3           Sadio Manee  101000000
# 4         Mohamed Salah   99500000
# 5             Neymar Jr   99500000
# 6        Joshua Kimmich   97000000
# 7       Virgil van Dijk   84500000
# 8     Lautaro Marte­nez   79500000
# 9  Gianluigi Donnarumma   78000000

# %%
type(asto_se_emena)
# Out:
# pandas.core.frame.DataFrame

# %%
fig, ax = plt.subplots(figsize=(30,10)) 
sns.barplot(x='player', y='value',data=asto_se_emena,ax=ax,color="lightblue")
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels(ax.get_xticklabels(), fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=15)
ax.set_title('MOST VALUABLE PLAYERS', fontsize=20)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
plt.gca().yaxis.set_major_formatter(tick)
None

# %%
fig, ax = plt.subplots(figsize=(20,10)) 
sns.barplot(x='country', y='value',data=countries,ax=ax,color="lightBlue")
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels(ax.get_xticklabels(), fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=15)
ax.set_title('MOST VALUABLE COUNTRIES', fontsize=20)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
plt.gca().yaxis.set_major_formatter(tick)

None

# %%
v_pre_team=df_3.groupby('club')['value'].sum().sort_values(ascending=False).reset_index().head(10)

# %%
v_pre_team
# Out:
#                    club      value
# 0      Manchester City   427033500
# 1   FC Bayern MÃ¼nchen   409543000
# 2             Paris SG   400725000
# 3       Manchester Utd   348327500
# 4            Liverpool   314188500
# 5              Arsenal   273935500
# 6               Brazil   215000000
# 7              Chelsea   213560000
# 8  AtlÃ©tico de Madrid   197750000
# 9         FC Barcelona   186345000

# %%
fig, ax = plt.subplots(figsize=(30,10)) 
sns.barplot(x='club', y='value',data=v_pre_team,ax=ax,color="lightblue")
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels(ax.get_xticklabels(), fontsize=15)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=15)
ax.set_title('MOST VALUABLE TEAMS', fontsize=20)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
plt.gca().yaxis.set_major_formatter(tick)
None

# %%
fig, ax = plt.subplots(figsize=(20,10)) 
sns.barplot(x='club', y='value',data=v_pre_team,ax=ax,color="lightblue").set(title='MOST VALUABLE SOCCER TEAMS')
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
plt.gca().yaxis.set_major_formatter(tick)
None
